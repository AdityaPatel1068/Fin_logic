# %%
from urllib. request import urlopen, Request
from bs4 import BeautifulSoup

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

# Initialize the base URL and the tickers
finviz_url = 'https://finviz.com/quote.ashx?t='
tickers = ['AMZN', 'GOOGL', 'AAPL', 'MSFT', 'FB']

# Initialize a dictionary to store news tables for each ticker
news_tables = {}

for ticker in tickers:
    url_1 = finviz_url + ticker
    req = Request(url=url_1, headers={'user-agent': 'my-app'})
    
    try:
        # Open the URL and parse the HTML content
        response = urlopen(req)
        html = BeautifulSoup(response, 'html.parser')
        
        # Find the news table by its ID
        news_table = html.find(id='news-table')
        
        # Store the news table in the dictionary, if found
        if news_table:
            news_tables[ticker] = news_table
        else:
            print(f"No news table found for {ticker}")
        
        # Optional: Break after the first iteration for testing
        break
        
    except Exception as e:
        print(f"An error occurred: {e}")

# Print the results
print(news_tables)
# Out:
# {'AMZN': <table border="0" cellpadding="1" cellspacing="0" class="fullview-news-outer news-table" id="news-table" width="100%">
# <tr class="cursor-pointer has-label" onclick="trackAndOpenNews(event, 'Insider Monkey', 'https://www.insidermonkey.com/blog/7-best-fast-money-stocks-to-buy-according-to-hedge-funds-1342810/');">
# <td align="right" width="130">
#             Aug-29-24 08:49PM
#         </td>
# <td align="left">
# <div class="news-link-container">
# <div class="news-link-left">
# <a class="tab-link-news" href="https://www.insidermonkey.com/blog/7-best-fast-money-stocks-to-buy-according-to-hedge-funds-1342810/" rel="nofollow" target="_blank">7 Best Fast Money Stocks To Buy According To Hedge Funds</a>
# </div>
# <div class="news-link-right flex gap-1 items-center">
# <span>(Insider Monkey)</span></div></div></td></tr>
# ...
